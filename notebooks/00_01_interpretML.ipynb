# %%
import os

path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date
from sklearn import preprocessing
from app.utils.visualization import plot_data
from app.utils.fetch_data import fred_fred, investing_api, alpha_vantage_api, alpha_vantage_api_financial_statements
from app.utils.fetch_data_fmp import FMP

from interpret import glassbox
from interpret import show
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_columns', None)

# %%
start_date = '2000-01-01'
today = date.today().strftime("%Y-%m-%d")

# %%
fmp = FMP()
# Out:
# 2022-10-01 18:57:31,859 [app.utils.fetch_data_fmp] [INFO] Financial Modeling Prep api ready.

# %% [markdown]
# # Gather data

# %%
apple = fmp.get_historical_daily_price('stock', 'aapl', start_date, today)
# Out:
# 2022-10-02 01:32:10,250 [app.utils.fetch_data_fmp] [INFO] Fetching daily price data of aapl

# %%
# market situation
sp500 = fmp.get_historical_daily_price("index", "%5EGSPC", start_date, today)
# Out:
# 2022-10-02 01:32:12,630 [app.utils.fetch_data_fmp] [INFO] Fetching daily price data of %5EGSPC

# %%
econ_indices = list()

for i in ["GDP", "realGDP", "nominalPotentialGDP", "realGDPPerCapita",
        "federalFunds", "CPI", "inflationRate", "inflation", "retailSales", "consumerSentiment", "durableGoods",
        "unemploymentRate", "totalNonfarmPayroll", "initialClaims", "industrialProductionTotalIndex",
        "newPrivatelyOwnedHousingUnitsStartedTotalUnits", "totalVehicleSales", "retailMoneyFunds",
        "smoothedUSRecessionProbabilities", "3MonthOr90DayRatesAndYieldsCertificatesOfDeposit",
        "commercialBankInterestRateOnCreditCardPlansAllAccounts", "30YearFixedRateMortgageAverage",
        "15YearFixedRateMortgageAverage"]:
    df = fmp.get_economic_index(i, start_date, today)
    econ_indices.append(df)
# Out:
# 2022-10-02 00:21:56,048 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: GDP
# 2022-10-02 00:21:56,864 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: realGDP
# 2022-10-02 00:21:57,701 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: nominalPotentialGDP
# 2022-10-02 00:21:58,536 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: realGDPPerCapita
# 2022-10-02 00:21:59,364 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: federalFunds
# 2022-10-02 00:22:00,257 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: CPI
# 2022-10-02 00:22:01,170 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: inflationRate
# 2022-10-02 00:22:02,895 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: inflation
# 2022-10-02 00:22:03,724 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: retailSales
# 2022-10-02 00:22:04,558 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: consumerSentiment
# 2022-10-02 00:22:05,393 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: durableGoods
# 2022-10-02 00:22:06,211 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: unemploymentRate
# 2022-10-02 00:22:07,117 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: totalNonfarmPayroll
# 2022-10-02 00:22:07,960 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: initialClaims
# 2022-10-02 00:22:09,474 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: industrialProductionTotalIndex
# 2022-10-02 00:22:10,397 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: newPrivatelyOwnedHousingUnitsStartedTotalUnits
# 2022-10-02 00:22:11,222 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: totalVehicleSales
# 2022-10-02 00:22:12,054 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: retailMoneyFunds
# 2022-10-02 00:22:12,871 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: smoothedUSRecessionProbabilities
# 2022-10-02 00:22:13,713 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: 3MonthOr90DayRatesAndYieldsCertificatesOfDeposit
# 2022-10-02 00:22:14,549 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: commercialBankInterestRateOnCreditCardPlansAllAccounts
# 2022-10-02 00:22:15,413 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: 30YearFixedRateMortgageAverage
# 2022-10-02 00:22:16,667 [app.utils.fetch_data_fmp] [INFO] Fetching economic index data: 15YearFixedRateMortgageAverage

# %% [markdown]
# # Preprocessing master table

# %%
dates = pd.date_range(start_date, today).tolist()
dates = [i.strftime("%Y-%m-%d") for i in dates]

master = pd.DataFrame(dates, columns=['date'])
master['date'] = pd.to_datetime(master['date'], format='%Y-%m-%d')

# %%
# apple stock related features
# create lag features
apple = apple[['date', 'adjClose', 'volume']]
apple.sort_values(by='date', ascending=False, inplace=True)
apple['volume'] = apple['volume'].shift(-1)
apple.rename(columns={"volume":"volume_lag1"}, inplace=True)

# %%
# market
sp500 = sp500[['date', 'adjClose', 'volume']]
sp500['adjClose'] = sp500['adjClose'].shift(-1)
sp500['volume'] = sp500['volume'].shift(-1)

sp500.sort_values(by='date', ascending=False, inplace=True)
sp500.rename(columns={"adjClose":"sp500_adjClose_lag1",
                      "volume":"sp500_volume_lag1"}, inplace=True)

# %% [markdown]
# create master dataset

# %%
master = master.merge(apple, on='date', how='left')
master = master.merge(sp500, on='date', how='left')

for econ_index_df in econ_indices:
    master = master.merge(econ_index_df, on='date', how='left')

# %% [markdown]
# preprocessing

# %%
def days_after_data_seen(s):
    """
    The days after the data release is the main feature that 'extends' the sparse data into daily data
    It comes from the logic that after an economic index is released,
        it might have an impact on the stock market, but the effect it has will gradually diminsh
    """
    not_na_indices= list(s.loc[s.notna()].index)
    num_days_after = list()

    for i in range(len(not_na_indices)-1):    
        if i==0:
            start = not_na_indices[i]

            num_days = start
            num_days_after.extend( list(np.sqrt(np.array(sorted(range(num_days+1), reverse=True)) + 1)) )

        start = not_na_indices[i]
        end = not_na_indices[i+1]

        num_days = end-start
        num_days_after.extend( list(np.sqrt(np.array(sorted(range(num_days), reverse=True)) + 1)) ) 
    
    if len(num_days_after) < len(s):
        fill_num = len(s) - len(num_days_after)
        num_days_after.extend([np.nan]*fill_num)
    elif len(num_days_after) > len(s):
        assert False, "Something is wrong"
        
    return num_days_after

# %% [markdown]
# fill in missing values of economic indices by considering the 'num_days_after_data_release'

# %%
# create num_days until missing
base_columns = [i for i in master.columns if i not in ['date', 'adjClose', 'volume_lag1',
                                                       'sp500_adjClose_lag1', 'sp500_volume_lag1']]

for c in base_columns:
    master[c+"_days_after_seen"] = days_after_data_seen(master[c])

# %%
# forward filling
base_columns = [i for i in master.columns if i not in ['date', 'adjClose']]
master.sort_values(by='date', inplace=True)
for i in base_columns:
    master[i] = master[i].fillna(method='ffill')
    
master.dropna(subset='adjClose', inplace=True)
master.reset_index(inplace=True, drop=True) # drop rows that are not trading days
# the reason this was done here is to merge all the economic statistics first
# the economic stats sometimes are released at a non-trading day

# %%
# cut the early days that cannot be inferred from the current data
nas = master.isna().sum(axis=1)
start_index = nas[nas==0].index.min()

master = master.loc[start_index:].reset_index(drop=True)

# %% [markdown]
# days_after_index_release * index

# %%
base_columns = [i for i in master.columns if i not in ['date', 'adjClose', 'volume_lag1',
                                                       'sp500_adjClose_lag1', 'sp500_volume_lag1']]

index_columns = [i for i in base_columns if 'days_after_seen' not in i]
days_columns = [i for i in base_columns if 'days_after_seen' in i]

assert len(index_columns)==len(days_columns)

for index in index_columns:
    days = index + "_days_after_seen"
    
    master[index + "_day_weighted"] = master[index] / master[days]

master.drop(columns = index_columns + days_columns, inplace=True)

# %%
# scale
base_columns = [i for i in master.columns if i not in ['date']]

scaler = preprocessing.StandardScaler(with_mean=False)
scaler.fit(master[base_columns])

scaled_values = scaler.transform(master[base_columns])
scaled_df = pd.DataFrame(scaled_values, columns=[i+'_scaled' for i in base_columns])

# append the existing target and date column
master = pd.concat([master, scaled_df], axis=1)

master.drop(columns=base_columns, inplace=True)

# %%
master
# Out:
#            date  adjClose_scaled  volume_lag1_scaled  \
# 0    2003-01-02         0.005223            0.510933
# 1    2003-01-03         0.005259            0.461813
# 2    2003-01-06         0.005259            0.375332
# 3    2003-01-07         0.005241            0.994071
# 4    2003-01-08         0.005135            0.871412
# ...         ...              ...                 ...
# 4967 2022-09-26         3.489974            0.244206
# 4968 2022-09-27         3.512890            0.237588
# 4969 2022-09-28         3.468446            0.214942
# 4970 2022-09-29         3.298080            0.373391
# 4971 2022-09-30         3.199008            0.326166
#
#       sp500_adjClose_lag1_scaled  sp500_volume_lag1_scaled  \
# 0                       0.900103                  0.796415
# 1                       0.929987                  0.899360
# 2                       0.929537                  0.827364
# 3                       0.950427                  1.050595
# 4                       0.944207                  1.130565
# ...                          ...                       ...
# 4967                    3.778373                  3.764246
# 4968                    3.739303                  3.575226
# 4969                    3.731374                  3.349600
# 4970                    3.804778                  3.427760
# 4971                    3.724397                  3.425830
#
#       GDP_day_weighted_scaled  realGDP_day_weighted_scaled  \
# 0                    0.283454                     0.421555
# 1                    0.285042                     0.423916
# 2                    0.289971                     0.431247
# 3                    0.291671                     0.433776
# 4                    0.293402                     0.436351
# ...                       ...                          ...
# 4967                 6.076098                     5.842059
# 4968                 6.076098                     5.842059
# 4969                 6.076098                     5.842059
# 4970                 6.076098                     5.842059
# 4971                 6.076098                     5.842059
#
#       nominalPotentialGDP_day_weighted_scaled  \
# 0                                    0.351135
# 1                                    0.353102
# 2                                    0.359208
# 3                                    0.361315
# 4                                    0.363459
# ...                                       ...
# 4967                                 7.338180
# 4968                                 7.338180
# 4969                                 7.338180
# 4970                                 7.338180
# 4971                                 7.338180
#
#       realGDPPerCapita_day_weighted_scaled  federalFunds_day_weighted_scaled  \
# 0                                 0.478375                          0.352722
# 1                                 0.481055                          0.358553
# 2                                 0.489373                          0.377948
# 3                                 0.492243                          0.385148
# 4                                 0.495165                          0.392775
# ...                                    ...                               ...
# 4967                              5.766651                          3.690186
# 4968                              5.766651                          3.690186
# 4969                              5.766651                          3.690186
# 4970                              5.766651                          3.690186
# 4971                              5.766651                          3.690186
#
#       CPI_day_weighted_scaled  inflationRate_day_weighted_scaled  \
# 0                    0.718465                           3.908194
# 1                    0.730341                           3.860534
# 2                    0.769847                           3.884364
# 3                    0.784512                           3.860534
# 4                    0.800049                           4.075008
# ...                       ...                                ...
# 4967                 6.476187                           5.528665
# 4968                 6.476187                           5.552496
# 4969                 6.476187                           5.552496
# 4970                 6.476187                           5.218869
# 4971                 6.476187                           5.218869
#
#       inflation_day_weighted_scaled  retailSales_day_weighted_scaled  \
# 0                          0.092039                         0.571302
# 1                          0.092166                         0.580745
# 2                          0.092548                         0.612159
# 3                          0.092676                         0.623821
# 4                          0.092805                         0.636175
# ...                             ...                              ...
# 4967                       3.638951                         7.107717
# 4968                       3.638951                         7.107717
# 4969                       3.638951                         7.107717
# 4970                       3.638951                         7.107717
# 4971                       3.638951                         7.107717
#
#       consumerSentiment_day_weighted_scaled  durableGoods_day_weighted_scaled  \
# 0                                  0.972343                          0.711909
# 1                                  0.988416                          0.723677
# 2                                  1.041882                          0.762823
# 3                                  1.061729                          0.777354
# 4                                  1.082756                          0.792749
# ...                                     ...                               ...
# 4967                               3.823810                          6.357579
# 4968                               3.823810                          6.357579
# 4969                               3.823810                          6.357579
# 4970                               3.823810                          6.357579
# 4971                               3.823810                          6.357579
#
#       unemploymentRate_day_weighted_scaled  \
# 0                                 0.803754
# 1                                 0.817040
# 2                                 0.861236
# 3                                 0.877642
# 4                                 0.895023
# ...                                    ...
# 4967                              2.854815
# 4968                              2.854815
# 4969                              2.854815
# 4970                              2.854815
# 4971                              2.854815
#
#       totalNonfarmPayroll_day_weighted_scaled  \
# 0                                    0.897218
# 1                                    0.912049
# 2                                    0.961384
# 3                                    0.979698
# 4                                    0.999099
# ...                                       ...
# 4967                                 5.843408
# 4968                                 5.843408
# 4969                                 5.843408
# 4970                                 5.843408
# 4971                                 5.843408
#
#       initialClaims_day_weighted_scaled  \
# 0                              1.127376
# 1                              1.380748
# 2                              0.765990
# 3                              0.839100
# 4                              0.938142
# ...                                 ...
# 4967                           0.921432
# 4968                           0.921432
# 4969                           0.921432
# 4970                           0.921432
# 4971                           0.921432
#
#       industrialProductionTotalIndex_day_weighted_scaled  \
# 0                                              0.896950
# 1                                              0.911776
# 2                                              0.961097
# 3                                              0.979405
# 4                                              0.998801
# ...                                                 ...
# 4967                                           5.722360
# 4968                                           5.722360
# 4969                                           5.722360
# 4970                                           5.722360
# 4971                                           5.722360
#
#       newPrivatelyOwnedHousingUnitsStartedTotalUnits_day_weighted_scaled  \
# 0                                              1.131041
# 1                                              1.149737
# 2                                              1.211929
# 3                                              1.235015
# 4                                              1.259474
# ...                                                 ...
# 4967                                           5.352593
# 4968                                           5.352593
# 4969                                           5.352593
# 4970                                           5.352593
# 4971                                           5.352593
#
#       totalVehicleSales_day_weighted_scaled  \
# 0                                  1.016251
# 1                                  1.033050
# 2                                  1.088930
# 3                                  1.109673
# 4                                  1.131649
# ...                                     ...
# 4967                               4.613495
# 4968                               4.613495
# 4969                               4.613495
# 4970                               4.613495
# 4971                               4.613495
#
#       retailMoneyFunds_day_weighted_scaled  \
# 0                                 0.949278
# 1                                 0.964970
# 2                                 1.017168
# 3                                 1.036544
# 4                                 1.057072
# ...                                    ...
# 4967                              6.599474
# 4968                              6.599474
# 4969                              6.599474
# 4970                              6.599474
# 4971                              6.599474
#
#       smoothedUSRecessionProbabilities_day_weighted_scaled  \
# 0                                              0.020879
# 1                                              0.021224
# 2                                              0.022372
# 3                                              0.022799
# 4                                              0.023250
# ...                                                 ...
# 4967                                           0.022794
# 4968                                           0.022794
# 4969                                           0.022794
# 4970                                           0.022794
# 4971                                           0.022794
#
#       3MonthOr90DayRatesAndYieldsCertificatesOfDeposit_day_weighted_scaled  \
# 0                                              0.344389
# 1                                              0.350081
# 2                                              0.369018
# 3                                              0.376048
# 4                                              0.383495
# ...                                                 ...
# 4967                                           4.102505
# 4968                                           4.102505
# 4969                                           4.102505
# 4970                                           4.102505
# 4971                                           4.102505
#
#       commercialBankInterestRateOnCreditCardPlansAllAccounts_day_weighted_scaled  \
# 0                                              0.927858
# 1                                              0.943196
# 2                                              0.994215
# 3                                              1.013155
# 4                                              1.033219
# ...                                                 ...
# 4967                                           5.962091
# 4968                                           5.962091
# 4969                                           5.962091
# 4970                                           5.962091
# 4971                                           5.962091
#
#       30YearFixedRateMortgageAverage_day_weighted_scaled  \
# 0                                              3.385242
# 1                                              4.722869
# 2                                              2.112131
# 3                                              2.361435
# 4                                              2.726750
# ...                                                 ...
# 4967                                           2.539047
# 4968                                           2.931839
# 4969                                           3.590754
# 4970                                           5.409098
# 4971                                           5.409098
#
#       15YearFixedRateMortgageAverage_day_weighted_scaled
# 0                                              3.188840
# 1                                              4.441886
# 2                                              1.986472
# 3                                              2.220943
# 4                                              2.564524
# ...                                                 ...
# 4967                                           2.305712
# 4968                                           2.662406
# 4969                                           3.260769
# 4970                                           5.052221
# 4971                                           5.052221
#
# [4972 rows x 28 columns]

# %% [markdown]
# # split dataset

# %%
master['date_y'] = master['date'].dt.year
master['date_m'] = master['date'].dt.month

# %%
train_end_date = '2017-01-01'
test_start_date = '2018-01-01'
test_end_date = '2021-01-01'
validation_date = '2022-01-01'

train = master.loc[master.date <= train_end_date].reset_index(drop=True)
test = master.loc[master.date.between(test_start_date, test_end_date, inclusive='left')].reset_index(drop=True)
valid = master.loc[master.date >= validation_date].reset_index(drop=True)

# %%
def split_xy(df, drop_list, target):
    x = df.drop(columns = drop_list + [target])
    y = df[target]
    return x,y

train_x, train_y = split_xy(train, ['date'], 'adjClose_scaled')
test_x, test_y = split_xy(test, ['date'], 'adjClose_scaled')
valid_x, valid_y = split_xy(valid, ['date'], 'adjClose_scaled')

# %% [markdown]
# # Glassbox model

# %%
from interpret import show
from interpret.data import Marginal

marginal = Marginal().explain_data(train_x, train_y, name = 'Train Data')
show(marginal)
# Out:
# <!-- http://127.0.0.1:7001/140161735875792/ -->
# <iframe src="http://127.0.0.1:7001/140161735875792/" width=100% height=800 frameBorder="0"></iframe>

# %%
from interpret.glassbox import ExplainableBoostingRegressor, LinearRegression, RegressionTree

ebm = ExplainableBoostingRegressor(random_state=123, n_jobs=-1)
ebm.fit(train_x, train_y)   #Works on dataframes and numpy arrays
# Out:
# ExplainableBoostingRegressor(feature_names=['volume_lag1_scaled',
#                                             'sp500_adjClose_lag1_scaled',
#                                             'sp500_volume_lag1_scaled',
#                                             'GDP_day_weighted_scaled',
#                                             'realGDP_day_weighted_scaled',
#                                             'nominalPotentialGDP_day_weighted_scaled',
#                                             'realGDPPerCapita_day_weighted_scaled',
#                                             'federalFunds_day_weighted_scaled',
#                                             'CPI_day_weighted_scaled',
#                                             'inflationRate_day_weighted_sca...
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'continuous', 'continuous',
#                                             'interaction', 'interaction', ...],
#                              n_jobs=-1, random_state=123)

# %% [markdown]
# #### Gloabl explanation

# %%
ebm_global = ebm.explain_global(name='EBM')
show(ebm_global)
# Out:
# <!-- http://127.0.0.1:7001/140161716082960/ -->
# <iframe src="http://127.0.0.1:7001/140161716082960/" width=100% height=800 frameBorder="0"></iframe>

# %%
ebm_local = ebm.explain_local(test_x[:5], test_y[:5], name='EBM')
show(ebm_local)
# Out:
# <!-- http://127.0.0.1:7001/140161712739760/ -->
# <iframe src="http://127.0.0.1:7001/140161712739760/" width=100% height=800 frameBorder="0"></iframe>

# %%
from interpret import show
from interpret.perf import RegressionPerf

ebm_perf = RegressionPerf(ebm.predict).explain_perf(test_y, test_y, name='EBM')
show(ebm_perf)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [548], in <cell line: 4>()
#       1 from interpret import show
#       2 from interpret.perf import RegressionPerf
# ----> 4 ebm_perf = RegressionPerf(ebm.predict).explain_perf(test_y, test_y, name='EBM')
#       5 show(ebm_perf)
#
# File ~/opt/anaconda3/envs/platform/lib/python3.8/site-packages/interpret/perf/regression.py:45, in RegressionPerf.explain_perf(self, X, y, name)
#      42 if name is None:
#      43     name = gen_name_from_class(self)
# ---> 45 X, y, self.feature_names, self.feature_types = unify_data(
#      46     X, y, self.feature_names, self.feature_types, missing_data_allowed=True
#      47 )
#      49 predict_fn = unify_predict_fn(self.predict_fn, X)
#      50 scores = predict_fn(X)
#
# File ~/opt/anaconda3/envs/platform/lib/python3.8/site-packages/interpret/utils/all.py:285, in unify_data(data, labels, feature_names, feature_types, missing_data_allowed)
#     282     new_data = data.values
#     284 if feature_names is None:
# --> 285     new_feature_names = list(data.columns)
#     286 else:
#     287     new_feature_names = feature_names
#
# File ~/opt/anaconda3/envs/platform/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'
