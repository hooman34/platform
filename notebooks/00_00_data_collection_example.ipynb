# %%
import os

path_parent = os.path.dirname(os.getcwd())
os.chdir(path_parent)

# %%
import pandas as pd
import numpy as np
from app.utils.visualization import plot_data
from app.utils.fetch_data import fred_fred, investing_api, yf_api, alpha_vantage_api, FMP, alpha_vantage_api_financial_statements
import investpy

# %% [markdown]
# # Economic indicators

# %%
# 10 year break even interest rate
fred_interestrate = fred_fred("T10YIE", '2022-01-01', '2022-07-30')
fred_interestrate.head()
# Out:
# 2022-08-13 21:53:01,407 [app.utils.fetch_data] [INFO] Fetching data from fred: T10YIE, from 2022-01-01 to 2022-07-30.
#         Date     v  symbol        type interval              p_key
# 0 2022-01-03  2.60  T10YIE  econ_index    daily  2022_01_03_T10YIE
# 1 2022-01-04  2.57  T10YIE  econ_index    daily  2022_01_04_T10YIE
# 2 2022-01-05  2.53  T10YIE  econ_index    daily  2022_01_05_T10YIE
# 3 2022-01-06  2.46  T10YIE  econ_index    daily  2022_01_06_T10YIE
# 4 2022-01-07  2.48  T10YIE  econ_index    daily  2022_01_07_T10YIE

# %% [markdown]
# # Stock data

# %%
invest_apple = investing_api("stock", "AAPL", '2022-01-01', '2022-07-30')
invest_apple.head()
# Out:
# 2022-08-13 21:53:04,940 [app.utils.fetch_data] [INFO] Fetching daily stock from investing_api: AAPL, from 01/01/2022 to 30/07/2022
#         Date    Open    High     Low   Close     Volume Currency symbol  \
# 0 2022-01-03  177.83  182.88  177.71  182.01  104701216      USD   AAPL
# 1 2022-01-04  182.63  182.94  179.12  179.70   99310440      USD   AAPL
# 2 2022-01-05  179.61  180.17  174.64  174.92   94537600      USD   AAPL
# 3 2022-01-06  172.70  175.30  171.64  172.00   96903952      USD   AAPL
# 4 2022-01-07  172.89  174.14  171.03  172.17   86709144      USD   AAPL
#
#     type interval            p_key
# 0  stock    daily  2022_01_03_AAPL
# 1  stock    daily  2022_01_04_AAPL
# 2  stock    daily  2022_01_05_AAPL
# 3  stock    daily  2022_01_06_AAPL
# 4  stock    daily  2022_01_07_AAPL

# %%
invest_apple = investing_api("stock", "AAPL", '2022-01-01', '2022-07-30', interval='monthly')
invest_apple.head()
# Out:
# 2022-08-13 21:53:06,602 [app.utils.fetch_data] [INFO] Fetching monthly stock from investing_api: AAPL, from 01/01/2022 to 30/07/2022
#         Date    Open    High     Low   Close      Volume Currency symbol  \
# 0 2022-01-01  177.83  182.94  154.70  174.78  2109283328      USD   AAPL
# 1 2022-02-01  174.01  176.65  152.00  165.12  1629275392      USD   AAPL
# 2 2022-03-01  164.69  179.61  150.10  174.61  2180882432      USD   AAPL
# 3 2022-04-01  174.03  178.49  155.38  157.65  1687873152      USD   AAPL
# 4 2022-05-01  156.71  166.48  132.61  148.84  2401040384      USD   AAPL
#
#     type interval            p_key
# 0  stock  monthly  2022_01_01_AAPL
# 1  stock  monthly  2022_02_01_AAPL
# 2  stock  monthly  2022_03_01_AAPL
# 3  stock  monthly  2022_04_01_AAPL
# 4  stock  monthly  2022_05_01_AAPL

# %%
alpha_apple = alpha_vantage_api('stock', 'AAPL', interval='daily')
alpha_apple.head()
# Out:
# 2022-08-13 21:53:09,470 [app.utils.fetch_data] [INFO] Fetching stock from alpha vantage api: AAPL
#         Date      Open      High       Low     Close    Volume Currency  \
# 0 2022-08-12  169.8200  172.1700  169.4000  172.1000  68039382      USD
# 1 2022-08-11  170.0600  170.9900  168.1900  168.4900  57149159      USD
# 2 2022-08-10  167.6800  169.3400  166.9000  169.2400  70170540      USD
# 3 2022-08-09  164.0200  165.8200  163.2500  164.9200  63135503      USD
# 4 2022-08-08  166.3700  167.8100  164.2000  164.8700  60362338      USD
#
#   symbol   type interval            p_key
# 0   AAPL  stock    daily  2022_08_12_AAPL
# 1   AAPL  stock    daily  2022_08_11_AAPL
# 2   AAPL  stock    daily  2022_08_10_AAPL
# 3   AAPL  stock    daily  2022_08_09_AAPL
# 4   AAPL  stock    daily  2022_08_08_AAPL

# %%
microsoft = yf_api('stock', 'MSFT')
microsoft.head()
# Out:
# 2022-08-13 21:53:09,504 [app.utils.fetch_data] [INFO] Fetching data from YahooFinance: MSFT, from None to None.
#         Date      Open      High       Low     Close      Volume  Dividends  \
# 0 1986-03-13  0.055654  0.063838  0.055654  0.061109  1031788800        0.0
# 1 1986-03-14  0.061109  0.064384  0.061109  0.063292   308160000        0.0
# 2 1986-03-17  0.063292  0.064929  0.063292  0.064384   133171200        0.0
# 3 1986-03-18  0.064383  0.064929  0.062201  0.062746    67766400        0.0
# 4 1986-03-19  0.062746  0.063292  0.061109  0.061655    47894400        0.0
#
#    Stock Splits Currency symbol   type interval            p_key
# 0           0.0      USD   MSFT  stock    daily  1986_03_13_MSFT
# 1           0.0      USD   MSFT  stock    daily  1986_03_14_MSFT
# 2           0.0      USD   MSFT  stock    daily  1986_03_17_MSFT
# 3           0.0      USD   MSFT  stock    daily  1986_03_18_MSFT
# 4           0.0      USD   MSFT  stock    daily  1986_03_19_MSFT

# %%
microsoft = yf_api('stock', 'MSFT', from_date='2022-01-01', to_date='2022-06-20', interval='weekly')
microsoft.head()
# Out:
# 2022-08-13 21:53:10,884 [app.utils.fetch_data] [INFO] Fetching data from YahooFinance: MSFT, from 2022-01-01 to 2022-06-20.
#         Date        Open        High         Low       Close       Volume  \
# 0 2022-01-03  333.880398  336.518779  308.731086  312.663788  173959800.0
# 1 2022-01-10  308.133696  321.992707  302.418861  308.840607  193260900.0
# 2 2022-01-17  302.737471  312.534345  294.314524  294.732697  181632200.0
# 3 2022-01-24  290.919501  307.148057  274.840251  306.909119  352234000.0
# 4 2022-01-31  307.596093  313.739037  298.645469  304.599274  202857400.0
#
#    Dividends  Stock Splits Currency symbol   type interval            p_key
# 0        0.0           0.0      USD   MSFT  stock   weekly  2022_01_03_MSFT
# 1        0.0           0.0      USD   MSFT  stock   weekly  2022_01_10_MSFT
# 2        0.0           0.0      USD   MSFT  stock   weekly  2022_01_17_MSFT
# 3        0.0           0.0      USD   MSFT  stock   weekly  2022_01_24_MSFT
# ...

# %% [markdown]
# # Index data

# %%
# S&P 500
invest_sp500 = investing_api("index", 'SPX', '2022-01-01', '2022-07-30')
invest_sp500.head()
# Out:
# 2022-08-13 21:53:21,235 [app.utils.fetch_data] [INFO] Fetching daily index from investing_api: SPX, from 01/01/2022 to 30/07/2022
#         Date     Open     High      Low    Close  Volume Currency symbol  \
# 0 2022-01-03  4778.14  4796.64  4758.17  4796.56       0      USD    SPX
# 1 2022-01-04  4804.51  4818.62  4774.27  4793.54       0      USD    SPX
# 2 2022-01-05  4787.99  4797.70  4699.44  4700.58       0      USD    SPX
# 3 2022-01-06  4693.39  4725.01  4671.26  4696.05       0      USD    SPX
# 4 2022-01-07  4697.66  4707.95  4662.74  4677.02       0      USD    SPX
#
#     type interval           p_key
# 0  index    daily  2022_01_03_SPX
# 1  index    daily  2022_01_04_SPX
# 2  index    daily  2022_01_05_SPX
# 3  index    daily  2022_01_06_SPX
# 4  index    daily  2022_01_07_SPX

# %%
# S&P 500
invest_sp500 = investing_api("index", 'SPX', '2022-01-01', '2022-07-30', interval="monthly")
invest_sp500.head()
# Out:
# 2022-08-13 21:53:22,942 [app.utils.fetch_data] [INFO] Fetching monthly index from investing_api: SPX, from 01/01/2022 to 30/07/2022
#         Date     Open     High      Low    Close  Volume Currency symbol  \
# 0 2022-01-01  4781.00  4817.88  4221.54  4515.55       0      USD    SPX
# 1 2022-02-01  4521.35  4595.10  4114.50  4373.79       0      USD    SPX
# 2 2022-03-01  4358.08  4637.90  4157.20  4530.41       0      USD    SPX
# 3 2022-04-01  4547.90  4593.90  4123.87  4131.93       0      USD    SPX
# 4 2022-05-01  4132.70  4307.90  3810.50  4132.15       0      USD    SPX
#
#     type interval           p_key
# 0  index  monthly  2022_01_01_SPX
# 1  index  monthly  2022_02_01_SPX
# 2  index  monthly  2022_03_01_SPX
# 3  index  monthly  2022_04_01_SPX
# 4  index  monthly  2022_05_01_SPX

# %% [markdown]
# # ETF

# %%
# VSPDR S&P 500 ETF (SPY)
vanguard500 = investing_api("etf", 'SPY', '2022-01-01', '2022-07-30')
vanguard500.head()
# Out:
# 2022-08-13 21:53:34,359 [app.utils.fetch_data] [INFO] Fetching daily etf from investing_api: SPY, from 01/01/2022 to 30/07/2022
#         Date    Open    High     Low   Close     Volume Currency Exchange  \
# 0 2022-01-03  476.30  477.85  473.85  477.71   71509600      USD     NYSE
# 1 2022-01-04  479.22  479.98  475.58  477.55   68191000      USD     NYSE
# 2 2022-01-05  477.16  477.98  468.28  468.38  100642304      USD     NYSE
# 3 2022-01-06  467.89  470.82  465.43  467.94   85719904      USD     NYSE
# 4 2022-01-07  467.95  469.20  464.65  466.09   85111600      USD     NYSE
#
#   symbol type interval           p_key
# 0    SPY  etf    daily  2022_01_03_SPY
# 1    SPY  etf    daily  2022_01_04_SPY
# 2    SPY  etf    daily  2022_01_05_SPY
# 3    SPY  etf    daily  2022_01_06_SPY
# 4    SPY  etf    daily  2022_01_07_SPY

# %%
# VSPDR S&P 500 ETF (SPY)
vanguard500 = investing_api("etf", 'SPY', '2022-01-01', '2022-07-30', interval='weekly')
vanguard500.head(3)
# Out:
# 2022-08-13 21:53:35,389 [app.utils.fetch_data] [INFO] Fetching weekly etf from investing_api: SPY, from 01/01/2022 to 30/07/2022
#         Date    Open    High     Low   Close     Volume Currency Exchange  \
# 0 2022-01-02  476.30  479.98  464.65  466.09  420356000      USD     NYSE
# 1 2022-01-09  462.70  473.20  456.60  464.72  448335008      USD     NYSE
# 2 2022-01-16  459.74  459.96  437.95  437.98  543881024      USD     NYSE
#
#   symbol type interval           p_key
# 0    SPY  etf   weekly  2022_01_02_SPY
# 1    SPY  etf   weekly  2022_01_09_SPY
# 2    SPY  etf   weekly  2022_01_16_SPY

# %% [markdown]
# # Fund

# %%
# eaton vance fund
eaton_investing = investing_api("fund", 'EAEAX', '2022-01-01', '2022-07-30')
eaton_investing.head()
# Out:
#         Date   Open   High    Low  Close Currency symbol  type interval  \
# 0 2022-01-03  31.60  31.60  31.60  31.60      USD  EAEAX  fund    daily
# 1 2022-01-04  31.64  31.64  31.64  31.64      USD  EAEAX  fund    daily
# 2 2022-01-05  31.01  31.01  31.01  31.01      USD  EAEAX  fund    daily
# 3 2022-01-06  31.03  31.03  31.03  31.03      USD  EAEAX  fund    daily
# 4 2022-01-07  30.88  30.88  30.88  30.88      USD  EAEAX  fund    daily
#
#               p_key
# 0  2022_01_03_EAEAX
# 1  2022_01_04_EAEAX
# 2  2022_01_05_EAEAX
# 3  2022_01_06_EAEAX
# 4  2022_01_07_EAEAX

# %% [markdown]
# # Financial statements

# %%
income = alpha_vantage_api_financial_statements("income statement", 'AAPL')
income.head(3)
# Out:
#   fiscalDateEnding reportedCurrency   grossProfit  totalRevenue costOfRevenue  \
# 0       2021-09-30              USD  152836000000  363172000000  234954000000
# 1       2020-09-30              USD  104956000000  271642000000  189475000000
# 2       2019-09-30              USD   98392000000  256598000000  180027000000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0               212981000000    108949000000                     21973000000
# 1               169559000000     66288000000                     19916000000
# 2               161782000000     63930000000                     18245000000
#
#   researchAndDevelopment operatingExpenses  ... incomeBeforeTax  \
# 0            21914000000       43887000000  ...    109207000000
# 1            18752000000       38668000000  ...     67091000000
# 2            16217000000       34462000000  ...     65737000000
#
#   incomeTaxExpense interestAndDebtExpense netIncomeFromContinuingOperations  \
# ...

# %%
balance = alpha_vantage_api_financial_statements("balance sheet", 'AAPL')
balance.head()
# Out:
#   fiscalDateEnding reportedCurrency   totalAssets totalCurrentAssets  \
# 0       2021-09-30              USD  351002000000       134836000000
# 1       2020-09-30              USD  323888000000       143713000000
# 2       2019-09-30              USD  338516000000       162819000000
# 3       2018-09-30              USD  365725000000       131339000000
# 4       2017-09-30              USD  375319000000       128645000000
#
#   cashAndCashEquivalentsAtCarryingValue cashAndShortTermInvestments  \
# 0                           34940000000                 62639000000
# 1                           38016000000                 90943000000
# 2                           48844000000                100557000000
# 3                           25913000000                 25913000000
# 4                           20289000000                 74181000000
#
#     inventory currentNetReceivables totalNonCurrentAssets  \
# 0  6580000000           51506000000          216166000000
# ...

# %%
cash = alpha_vantage_api_financial_statements("cash flow", 'AAPL')
cash
# Out:
#   fiscalDateEnding reportedCurrency operatingCashflow  \
# 0       2021-09-30              USD      104038000000
# 1       2020-09-30              USD       80674000000
# 2       2019-09-30              USD       69391000000
# 3       2018-09-30              USD       77434000000
# 4       2017-09-30              USD       64225000000
#
#   paymentsForOperatingActivities proceedsFromOperatingActivities  \
# 0                     4087000000                            None
# 1                     4502000000                            None
# 2                     3423000000                            None
# 3                     3022000000                            None
# 4                     2092000000                            None
#
#   changeInOperatingLiabilities changeInOperatingAssets  \
# 0                  19801000000             24712000000
# 1                   6935000000              1245000000
# 2                  -7248000000             -3760000000
# ...

# %%
earnings = alpha_vantage_api_financial_statements("earnings", 'AAPL')
earnings.head()
# Out:
#   fiscalDateEnding reportedEPS symbol            p_key
# 0       2022-06-30        4.82   AAPL  2022_06_30_AAPL
# 1       2021-09-30        5.62   AAPL  2021_09_30_AAPL
# 2       2020-09-30        3.27   AAPL  2020_09_30_AAPL
# 3       2019-09-30        2.98   AAPL  2019_09_30_AAPL
# 4       2018-09-30        2.97   AAPL  2018_09_30_AAPL

# %% [markdown]
# # Search options

# %% [markdown]
# ### Investpy search

# %% [markdown]
# For more search options, go to the official documentation: https://investpy.readthedocs.io/_info/introduction.html

# %%
investpy.indices.search_indices('name', 'S&P 500').head(4)
# Out:
#          country                            name  \
# 0  united states  S&P 500 Consumer Discretionary
# 1  united states        S&P 500 Consumer Staples
# 2  united states                         S&P 500
# 3  united states                  S&P 500 Energy
#
#                         full_name  symbol currency            class  \
# 0  S&P 500 Consumer Discretionary  SPLRCD      USD  primary_sectors
# 1        S&P 500 Consumer Staples  SPLRCS      USD  primary_sectors
# 2                         S&P 500     SPX      USD    major_indices
# 3                  S&P 500 Energy    SPNY      USD  primary_sectors
#
#           market
# 0  world_indices
# 1  world_indices
# 2  world_indices
# 3  world_indices

# %% [markdown]
# ### Fred search

# %%
fred.

# %% [markdown]
# ----
# END
